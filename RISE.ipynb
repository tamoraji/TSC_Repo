# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.model_selection import cross_val_predict, KFold
import sklearn
import numpy as np
import os
import sys

# %%
# define a list of datasets
datasets = [
"BEARING_Univar",
"PHM2022_Multivar",
"PHM2022_Univar_PIN",
"PHM2022_Univar_PO",
"PHM2022_Univar_PDIN",
"ETCHING_Multivar",
"MFPT_48KHZ_Univar",
"MFPT_96KHZ_Univar",
"PADERBORN_6KHZ_Univar",
"PADERBORN_4KHZ_Univar",
"PADERBORN_64KHZ_Multivar",
"PADERBORN_4KHZ_Multivar",
"Hydraulic_systems_10HZ_Multivar",
"Hydraulic_systems_100HZ_Multivar",
"Gas_sensors_home_activity",
"Control_charts",
"CWRU_12k_DE_univar",
"CWRU_12k_DE_multivar",
"CWRU_12k_FE_univar",
"CWRU_12k_FE_multivar",
"CWRU_48k_DE_univar",
"CWRU_48k_DE_multivar"
]
datasets = ["Control_charts", "PHM2022_Multivar", "PHM2022_Univar_PDIN"]
datasets_path = "../datasets"

for dataset in datasets:
    Dataset_name = dataset + "_Dataset"
    Dataset = np.load(datasets_path + "/" + Dataset_name + ".npy")
    print(Dataset.shape)
    

    Labels_name = dataset + "_Labels"
    Labels = np.load(datasets_path + "/"  + Labels_name + ".npy")
# Out:
# (600, 60, 1)
# (53785, 749, 3)
# (53785, 749, 1)

# %%
# change this directory for your machine
root_dir = './'


# define a list of algorithms
algorirhms_path = "./classifiers"

from classifiers import RISE_module


# define the number of folds
n_folds = 5

# perform cross-validation for each dataset and algorithm combination
for dataset in datasets:
    Dataset_name = dataset + "_Dataset"
    Dataset = np.load(datasets_path + "/" + Dataset_name + ".npy")
    

    Labels_name = dataset + "_Labels"
    Labels = np.load(datasets_path + "/"  + Labels_name + ".npy")

    # Create a folder for results
    results_path = root_dir + "Results/" + Dataset_name
    if os.path.exists(results_path):
        pass
    else:
        try:
            os.makedirs(results_path)
        except:
            # in case another machine created the path meanwhile !:(
            pass



    #Run The RISE Module
    RISE_module.RISE(results_path, Dataset_name, Dataset, Labels, nb_folds=n_folds,
                n_estimators = 200,
                n_jobs=10)
# Out:
#  The dataset shape is:(600, 60, 1)
#
#  The number of data samples (N) is:600
#
#  The number of TS length (T) is:60
#
#  The number of TS dimention (M) is:1
#
#  The classifier is fitted
# 0.6833333333333333
# 0.6790204165204164
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       1.00      1.00      1.00        19
#            2       0.56      0.43      0.49        21
#            3       0.50      0.60      0.55        20
#            4       0.54      0.71      0.61        21
#            5       0.60      0.43      0.50        21
#
#     accuracy                           0.68       120
#    macro avg       0.70      0.70      0.69       120
# weighted avg       0.69      0.68      0.68       120
#
#  fold 1 is Finished!
#
#  The classifier is fitted
# 0.6416666666666667
# 0.6340234778121775
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        17
#            1       1.00      1.00      1.00        23
#            2       0.41      0.63      0.50        19
#            3       0.47      0.28      0.35        25
#            4       0.57      0.40      0.47        20
#            5       0.45      0.62      0.53        16
#
#     accuracy                           0.64       120
#    macro avg       0.65      0.66      0.64       120
# weighted avg       0.65      0.64      0.63       120
#
#  fold 2 is Finished!
#
#  The classifier is fitted
# 0.6416666666666667
# 0.6383803654802731
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        16
#            1       1.00      1.00      1.00        19
#            2       0.71      0.45      0.56        22
#            3       0.50      0.75      0.60        16
#            4       0.34      0.56      0.43        18
#            5       0.59      0.34      0.43        29
#
#     accuracy                           0.64       120
#    macro avg       0.68      0.68      0.66       120
# weighted avg       0.68      0.64      0.64       120
#
#  fold 3 is Finished!
#
#  The classifier is fitted
# 0.7333333333333333
# 0.728888968344775
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        24
#            1       1.00      1.00      1.00        20
#            2       0.55      0.75      0.63        16
#            3       0.69      0.47      0.56        19
#            4       0.60      0.43      0.50        21
#            5       0.54      0.70      0.61        20
#
#     accuracy                           0.73       120
#    macro avg       0.73      0.73      0.72       120
# weighted avg       0.74      0.73      0.73       120
#
#  fold 4 is Finished!
#
#  The classifier is fitted
# 0.6916666666666667
# 0.6929778497255893
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        25
#            1       1.00      1.00      1.00        19
#            2       0.52      0.50      0.51        22
#            3       0.50      0.50      0.50        20
#            4       0.61      0.55      0.58        20
#            5       0.41      0.50      0.45        14
#
#     accuracy                           0.69       120
#    macro avg       0.67      0.67      0.67       120
# weighted avg       0.70      0.69      0.69       120
#
#  fold 5 is Finished!
#  Finished!
# Total time elapsed: 7.6778s
#
#  The dataset shape is:(53785, 749, 3)
#
#  The number of data samples (N) is:53785
#
#  The number of TS length (T) is:749
#
#  The number of TS dimention (M) is:3
# RISE is not capable of doing classification on MTS. so it will be done on only the first dimension
#
#  The classifier is fitted
# 0.9820581946639397
# 0.9819786673162688
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      3949
#            1       0.98      0.92      0.95       624
#            2       0.99      0.99      0.99       733
#            3       1.00      0.98      0.99       588
#            4       1.00      1.00      1.00       609
#            5       0.98      0.97      0.97       645
#            6       0.99      1.00      1.00       605
#            7       0.99      0.97      0.98       662
#            8       0.99      0.96      0.97       587
#            9       1.00      1.00      1.00       626
#           10       1.00      0.97      0.99       509
#           11       0.98      0.95      0.96       620
#
#     accuracy                           0.98     10757
#    macro avg       0.99      0.97      0.98     10757
# weighted avg       0.98      0.98      0.98     10757
#
#  fold 1 is Finished!
#
#  The classifier is fitted
# 0.9772241331226178
# 0.9770785995107251
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      3917
#            1       0.99      0.90      0.94       660
#            2       0.99      0.99      0.99       670
#            3       0.99      0.97      0.98       633
#            4       1.00      1.00      1.00       681
#            5       0.97      0.96      0.96       601
#            6       0.99      1.00      1.00       618
#            7       0.99      0.96      0.98       596
#            8       0.99      0.97      0.98       606
#            9       1.00      1.00      1.00       589
#           10       1.00      0.95      0.97       546
#           11       0.97      0.92      0.94       640
#
#     accuracy                           0.98     10757
#    macro avg       0.99      0.97      0.98     10757
# weighted avg       0.98      0.98      0.98     10757
#
#  fold 2 is Finished!
#
#  The classifier is fitted
# 0.9826159709956308
# 0.9825114969577238
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      3864
#            1       0.98      0.91      0.95       633
#            2       1.00      0.99      0.99       692
#            3       0.99      0.98      0.99       607
#            4       1.00      1.00      1.00       601
#            5       0.97      0.98      0.98       632
#            6       0.99      1.00      0.99       627
#            7       0.99      0.98      0.99       619
#            8       0.99      0.98      0.98       680
#            9       1.00      1.00      1.00       612
#           10       1.00      0.95      0.97       546
#           11       0.98      0.95      0.96       644
#
#     accuracy                           0.98     10757
#    macro avg       0.99      0.98      0.98     10757
# weighted avg       0.98      0.98      0.98     10757
#
#  fold 3 is Finished!
#
#  The classifier is fitted
# 0.9815933810541972
# 0.981508347763415
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      3932
#            1       0.98      0.92      0.95       605
#            2       0.99      1.00      0.99       689
#            3       1.00      0.98      0.99       633
#            4       1.00      1.00      1.00       627
#            5       0.98      0.96      0.97       626
#            6       0.99      1.00      1.00       592
#            7       1.00      0.98      0.99       621
#            8       0.99      0.97      0.98       620
#            9       1.00      1.00      1.00       618
#           10       1.00      0.95      0.97       556
#           11       0.97      0.95      0.96       638
#
#     accuracy                           0.98     10757
#    macro avg       0.99      0.97      0.98     10757
# weighted avg       0.98      0.98      0.98     10757
#
#  fold 4 is Finished!
#
#  The classifier is fitted
# 0.9784326485079483
# 0.9783111040900438
#               precision    recall  f1-score   support
#
#            0       0.96      1.00      0.98      3918
#            1       0.98      0.90      0.94       661
#            2       1.00      0.98      0.99       708
#            3       1.00      0.98      0.99       609
#            4       1.00      1.00      1.00       583
#            5       0.97      0.95      0.96       570
#            6       0.99      0.99      0.99       616
#            7       0.99      0.98      0.99       656
#            8       0.99      0.97      0.98       626
#            9       1.00      1.00      1.00       612
#           10       1.00      0.95      0.97       534
#           11       0.98      0.95      0.96       664
#
#     accuracy                           0.98     10757
#    macro avg       0.99      0.97      0.98     10757
# weighted avg       0.98      0.98      0.98     10757
#
#  fold 5 is Finished!
#  Finished!
# Total time elapsed: 2966.6067s
#
#  The dataset shape is:(53785, 749, 1)
#
#  The number of data samples (N) is:53785
#
#  The number of TS length (T) is:749
#
#  The number of TS dimention (M) is:1
#  The classifier is fitted
# 0.9827089337175793
# 0.9826229923409562
#               precision    recall  f1-score   support
#
#            0       0.97      1.00      0.98      3985
#            1       0.98      0.92      0.95       609
#            2       0.99      0.99      0.99       716
#            3       0.99      0.98      0.99       608
#            4       1.00      1.00      1.00       650
#            5       0.97      0.96      0.97       605
#            6       0.99      1.00      0.99       577
#            7       0.99      0.98      0.99       593
#            8       0.99      0.98      0.98       623
#            9       1.00      1.00      1.00       602
#           10       1.00      0.96      0.98       536
#           11       0.98      0.95      0.96       653
#
#     accuracy                           0.98     10757
#    macro avg       0.99      0.98      0.98     10757
# weighted avg       0.98      0.98      0.98     10757
#
#  fold 1 is Finished!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_384100/2423297468.py in <module>
#      35
#      36     #Run The RISE Module
# ---> 37     RISE_module.RISE(results_path, Dataset_name, Dataset, Labels, nb_folds=n_folds,
#      38                 n_estimators = 200,
#      39                 n_jobs=10)
#
# ~/Moji/TSC_Repo/classifiers/RISE_module.py in RISE(results_path, dataset_name, dataset, labels, nb_folds, n_estimators, n_jobs)
#      70         # fit the algorithm on the training data
#      71
# ---> 72         classifier.fit(X_train, y_train)
#      73         print("\n The classifier is fitted")
#      74
#
# ~/.local/lib/python3.10/site-packages/sktime/classification/base.py in fit(self, X, y)
#     189
#     190         # pass coerced and checked data to inner _fit
# --> 191         self._fit(X, y)
#     192         self.fit_time_ = int(round(time.time() * 1000)) - start
#     193
#
# ~/.local/lib/python3.10/site-packages/sktime/classification/interval_based/_rise.py in _fit(self, X, y)
#     277
#     278         # Parallel loop
# --> 279         worker_rets = Parallel(n_jobs=self._threads_to_use)(
#     280             delayed(_parallel_build_trees)(
#     281                 X,
#
# ~/.local/lib/python3.10/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# ~/.local/lib/python3.10/site-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# ~/.local/lib/python3.10/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     565         AsyncResults.get from multiprocessing."""
#     566         try:
# --> 567             return future.result(timeout=timeout)
#     568         except CfTimeoutError as e:
#     569             raise TimeoutError from e
#
# /usr/lib/python3.10/concurrent/futures/_base.py in result(self, timeout)
#     451                     return self.__get_result()
#     452
# --> 453                 self._condition.wait(timeout)
#     454
#     455                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     318         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319             if timeout is None:
# --> 320                 waiter.acquire()
#     321                 gotit = True
#     322             else:
#
# KeyboardInterrupt:
