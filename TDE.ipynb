# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.model_selection import cross_val_predict, KFold
import sklearn
import numpy as np
import os
import sys
import time

# %%
# define a list of datasets
datasets = [
"Control_charts",
"ETCHING_Multivar",
"Hydraulic_systems_10HZ_Multivar",
"Gas_sensors_home_activity",
"CWRU_12k_DE_univar",
"CWRU_12k_DE_multivar",
"CWRU_12k_FE_univar",
"CWRU_12k_FE_multivar",
"CWRU_48k_DE_univar",
"CWRU_48k_DE_multivar",
"Hydraulic_systems_100HZ_Multivar",
"PHM2022_Multivar",
"PHM2022_Univar_PIN",
"PHM2022_Univar_PO",
"PHM2022_Univar_PDIN",
"MFPT_48KHZ_Univar",
"MFPT_96KHZ_Univar",
"PADERBORN_64KHZ_Univar",
"PADERBORN_4KHZ_Univar",
"PADERBORN_64KHZ_Multivar",
"PADERBORN_4KHZ_Multivar",
"BEARING_Univar",
]


datasets_path = "../datasets"

for dataset in datasets:
    Dataset_name = dataset + "_Dataset"
    Dataset = np.load(datasets_path + "/" + Dataset_name + ".npy")
    print(Dataset.shape)
    

    Labels_name = dataset + "_Labels"
    Labels = np.load(datasets_path + "/"  + Labels_name + ".npy")
# Out:
# (600, 60, 1)
# (53785, 749, 3)
# (53785, 749, 1)

# %%
# change this directory for your machine
root_dir = './'


# define a list of algorithms
algorirhms_path = "./classifiers"

from classifiers import TDE_module


# define the number of folds
n_folds = 5

# perform cross-validation for each dataset and algorithm combination
for dataset in datasets:
    Dataset_name = dataset + "_Dataset"
    Dataset = np.load(datasets_path + "/" + Dataset_name + ".npy")
    start = time.time() ##Start timing
    print(f"Starting to work on {Dataset_name} at {start}")
    

    Labels_name = dataset + "_Labels"
    Labels = np.load(datasets_path + "/"  + Labels_name + ".npy")

    # Create a folder for results
    results_path = root_dir + "Results/" + Dataset_name
    if os.path.exists(results_path):
        pass
    else:
        try:
            os.makedirs(results_path)
        except:
            # in case another machine created the path meanwhile !:(
            pass



    #Run The TDE Module
    TDE_module.TDE(results_path, Dataset_name, Dataset, Labels, nb_folds=n_folds,
                n_parameter_samples= 250, 
                max_ensemble_size=50, 
                randomly_selected_params = 50,
                n_jobs=10)

    print(f"Working on {Dataset_name} finished successfully!")
# Out:
#  The dataset shape is:(600, 60, 1)
#
#  The number of data samples (N) is:600
#
#  The number of TS length (T) is:60
#
#  The number of TS dimention (M) is:1
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:33: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   d[key] = value
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:33: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   d[key] = value
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:33: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   d[key] = value
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:33: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   d[key] = value
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:33: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   d[key] = value
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:33: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   d[key] = value
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:33: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   d[key] = value
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:33: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   d[key] = value
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:33: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   d[key] = value
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:33: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   d[key] = value
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:33: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   d[key] = value
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
# /home/ma00048/.local/lib/python3.10/site-packages/numba/typed/typeddict.py:53: NumbaTypeSafetyWarning: unsafe cast from int64 to uint32. Precision may be lost.
#   return d.get(key, default)
#  The classifier is fitted
# 0.9833333333333333
# 0.9833551293228713
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        15
#            1       1.00      1.00      1.00        22
#            2       1.00      0.95      0.97        19
#            3       1.00      0.96      0.98        25
#            4       0.96      1.00      0.98        24
#            5       0.94      1.00      0.97        15
#
#     accuracy                           0.98       120
#    macro avg       0.98      0.98      0.98       120
# weighted avg       0.98      0.98      0.98       120
#
#  fold 1 is Finished!
#
#  The classifier is fitted
# 1.0
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        24
#            1       1.00      1.00      1.00        25
#            2       1.00      1.00      1.00        14
#            3       1.00      1.00      1.00        13
#            4       1.00      1.00      1.00        22
#            5       1.00      1.00      1.00        22
#
#     accuracy                           1.00       120
#    macro avg       1.00      1.00      1.00       120
# weighted avg       1.00      1.00      1.00       120
#
#  fold 2 is Finished!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_351041/1785115507.py in <module>
#      35
#      36     #Run The TDE Module
# ---> 37     TDE_module.TDE(results_path, Dataset_name, Dataset, Labels, nb_folds=n_folds,
#      38                 n_parameter_samples= 250,
#      39                 max_ensemble_size=50,
#
# ~/Moji/TSC_Repo/classifiers/TDE_module.py in TDE(results_path, dataset_name, dataset, labels, nb_folds, n_parameter_samples, max_ensemble_size, randomly_selected_params, n_jobs)
#      92         # fit the algorithm on the training data
#      93
# ---> 94         classifier.fit(X_train, y_train)
#      95         print("\n The classifier is fitted")
#      96
#
# ~/.local/lib/python3.10/site-packages/sktime/classification/base.py in fit(self, X, y)
#     189
#     190         # pass coerced and checked data to inner _fit
# --> 191         self._fit(X, y)
#     192         self.fit_time_ = int(round(time.time() * 1000)) - start
#     193
#
# ~/.local/lib/python3.10/site-packages/sktime/classification/dictionary_based/_tde.py in _fit(self, X, y)
#     333             tde._subsample = subsample
#     334
# --> 335             tde._accuracy = self._individual_train_acc(
#     336                 tde,
#     337                 y_subsample,
#
# ~/.local/lib/python3.10/site-packages/sktime/classification/dictionary_based/_tde.py in _individual_train_acc(self, tde, y, train_size, lowest_acc)
#     510
#     511         if self._threads_to_use > 1:
# --> 512             c = Parallel(n_jobs=self._threads_to_use, prefer="threads")(
#     513                 delayed(tde._train_predict)(
#     514                     i,
#
# ~/.local/lib/python3.10/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1096
#    1097             with self._backend.retrieval_context():
# -> 1098                 self.retrieve()
#    1099             # Make sure that we get a last message telling us we are done
#    1100             elapsed_time = time.time() - self._start_time
#
# ~/.local/lib/python3.10/site-packages/joblib/parallel.py in retrieve(self)
#     973             try:
#     974                 if getattr(self._backend, 'supports_timeout', False):
# --> 975                     self._output.extend(job.get(timeout=self.timeout))
#     976                 else:
#     977                     self._output.extend(job.get())
#
# /usr/lib/python3.10/multiprocessing/pool.py in get(self, timeout)
#     766
#     767     def get(self, timeout=None):
# --> 768         self.wait(timeout)
#     769         if not self.ready():
#     770             raise TimeoutError
#
# /usr/lib/python3.10/multiprocessing/pool.py in wait(self, timeout)
#     763
#     764     def wait(self, timeout=None):
# --> 765         self._event.wait(timeout)
#     766
#     767     def get(self, timeout=None):
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     605             signaled = self._flag
#     606             if not signaled:
# --> 607                 signaled = self._cond.wait(timeout)
#     608             return signaled
#     609
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     318         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319             if timeout is None:
# --> 320                 waiter.acquire()
#     321                 gotit = True
#     322             else:
#
# KeyboardInterrupt:
