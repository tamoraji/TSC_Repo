# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.model_selection import cross_val_predict, KFold
import sklearn
import numpy as np
import os
import sys

# %%
# define a list of datasets
datasets = ["PHM2022_Multivar", "PHM2022_Univar_PDIN"]
datasets_path = "../datasets"

for dataset in datasets:
    Dataset_name = dataset + "_Dataset"
    Dataset = np.load(datasets_path + "/" + Dataset_name + ".npy")
    print(Dataset.shape)
    

    Labels_name = dataset + "_Labels"
    Labels = np.load(datasets_path + "/"  + Labels_name + ".npy")
# Out:
# (53785, 749, 3)
# (53785, 749, 1)

# %%
# change this directory for your machine
root_dir = './'


# define a list of algorithms
algorirhms_path = "./classifiers"

from classifiers import CIF_module


# define the number of folds
n_folds = 5

# perform cross-validation for each dataset and algorithm combination
for dataset in datasets:
    Dataset_name = dataset + "_Dataset"
    Dataset = np.load(datasets_path + "/" + Dataset_name + ".npy")
    

    Labels_name = dataset + "_Labels"
    Labels = np.load(datasets_path + "/"  + Labels_name + ".npy")

    # Create a folder for results
    results_path = root_dir + "Results/" + Dataset_name
    if os.path.exists(results_path):
        pass
    else:
        try:
            os.makedirs(results_path)
        except:
            # in case another machine created the path meanwhile !:(
            pass



    #Run The CIF Module
    CIF_module.CIF(results_path, Dataset_name, Dataset, Labels, nb_folds=n_folds, n_estimators=500, att_subsample_size= 8)
# Out:
#  The dataset shape is:(53785, 749, 3)
#
#  The number of data samples (N) is:53785
#
#  The number of TS length (T) is:749
#
#  The number of TS dimention (M) is:3
# [Pipeline] ............ (step 1 of 2) Processing rocket, total=  26.2s
# [Pipeline] . (step 2 of 2) Processing ridgeclassifiercv, total=  11.9s
# 0.997397043785442
# 0.9973946054235139
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3913
#            1       1.00      0.98      0.99       643
#            2       1.00      0.99      1.00       714
#            3       1.00      1.00      1.00       575
#            4       1.00      1.00      1.00       614
#            5       1.00      1.00      1.00       625
#            6       0.99      1.00      0.99       626
#            7       1.00      1.00      1.00       604
#            8       1.00      1.00      1.00       632
#            9       1.00      1.00      1.00       634
#           10       1.00      1.00      1.00       539
#           11       1.00      1.00      1.00       638
#
#     accuracy                           1.00     10757
#    macro avg       1.00      1.00      1.00     10757
# weighted avg       1.00      1.00      1.00     10757
#
#  fold 1 is Finished!
# [Pipeline] ............ (step 1 of 2) Processing rocket, total=  23.4s
# [Pipeline] . (step 2 of 2) Processing ridgeclassifiercv, total=  12.0s
# 0.998698521892721
# 0.9986977660519482
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3924
#            1       1.00      0.99      1.00       638
#            2       1.00      1.00      1.00       676
#            3       1.00      1.00      1.00       621
#            4       1.00      1.00      1.00       622
#            5       1.00      1.00      1.00       619
#            6       1.00      1.00      1.00       611
#            7       1.00      1.00      1.00       639
#            8       1.00      1.00      1.00       666
#            9       1.00      1.00      1.00       592
#           10       1.00      1.00      1.00       493
#           11       1.00      1.00      1.00       656
#
#     accuracy                           1.00     10757
#    macro avg       1.00      1.00      1.00     10757
# weighted avg       1.00      1.00      1.00     10757
#
#  fold 2 is Finished!
# [Pipeline] ............ (step 1 of 2) Processing rocket, total=  23.3s
# [Pipeline] . (step 2 of 2) Processing ridgeclassifiercv, total=  11.9s
# 0.997768894673236
# 0.997763448934346
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      3881
#            1       1.00      0.98      0.99       650
#            2       1.00      0.99      1.00       706
#            3       1.00      1.00      1.00       591
#            4       1.00      1.00      1.00       640
#            5       1.00      1.00      1.00       636
#            6       1.00      1.00      1.00       581
#            7       1.00      1.00      1.00       658
#            8       1.00      1.00      1.00       587
#            9       1.00      1.00      1.00       627
#           10       1.00      1.00      1.00       600
#           11       1.00      1.00      1.00       600
#
#     accuracy                           1.00     10757
#    macro avg       1.00      1.00      1.00     10757
# weighted avg       1.00      1.00      1.00     10757
#
#  fold 3 is Finished!
# [Pipeline] ............ (step 1 of 2) Processing rocket, total=  23.4s
# [Pipeline] . (step 2 of 2) Processing ridgeclassifiercv, total=  11.8s
# 0.9980477828390816
# 0.998041384048459
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      3922
#            1       1.00      0.98      0.99       658
#            2       1.00      1.00      1.00       644
#            3       1.00      1.00      1.00       647
#            4       1.00      1.00      1.00       624
#            5       1.00      1.00      1.00       582
#            6       1.00      1.00      1.00       636
#            7       1.00      1.00      1.00       630
#            8       1.00      1.00      1.00       571
#            9       1.00      1.00      1.00       606
#           10       1.00      1.00      1.00       574
#           11       1.00      1.00      1.00       663
#
#     accuracy                           1.00     10757
#    macro avg       1.00      1.00      1.00     10757
# weighted avg       1.00      1.00      1.00     10757
#
#  fold 4 is Finished!
# [Pipeline] ............ (step 1 of 2) Processing rocket, total=  24.0s
# [Pipeline] . (step 2 of 2) Processing ridgeclassifiercv, total=  11.7s
# 0.9972111183415451
# 0.9972032692640528
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      3940
#            1       1.00      0.97      0.99       594
#            2       1.00      0.99      1.00       752
#            3       1.00      1.00      1.00       636
#            4       1.00      1.00      1.00       601
#            5       1.00      1.00      1.00       612
#            6       1.00      1.00      1.00       604
#            7       1.00      1.00      1.00       623
#            8       1.00      1.00      1.00       663
#            9       1.00      1.00      1.00       598
#           10       1.00      1.00      1.00       485
#           11       1.00      1.00      1.00       649
#
#     accuracy                           1.00     10757
#    macro avg       1.00      1.00      1.00     10757
# weighted avg       1.00      1.00      1.00     10757
#
#  fold 5 is Finished!
#  Finished!
# Total time elapsed: 210.5703s
#
#  The dataset shape is:(53785, 749, 1)
#
#  The number of data samples (N) is:53785
#
#  The number of TS length (T) is:749
#
#  The number of TS dimention (M) is:1
# [Pipeline] ............ (step 1 of 2) Processing rocket, total=  11.0s
# [Pipeline] . (step 2 of 2) Processing ridgeclassifiercv, total=  11.8s
# 0.9931207585758111
# 0.9931096892226254
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      3871
#            1       1.00      0.96      0.98       661
#            2       0.99      0.99      0.99       742
#            3       1.00      1.00      1.00       623
#            4       1.00      1.00      1.00       638
#            5       0.98      1.00      0.99       616
#            6       0.99      0.99      0.99       574
#            7       0.99      0.99      0.99       651
#            8       1.00      0.99      1.00       633
#            9       1.00      1.00      1.00       576
#           10       1.00      1.00      1.00       524
#           11       1.00      1.00      1.00       648
#
#     accuracy                           0.99     10757
#    macro avg       0.99      0.99      0.99     10757
# weighted avg       0.99      0.99      0.99     10757
#
#  fold 1 is Finished!
# [Pipeline] ............ (step 1 of 2) Processing rocket, total=  11.2s
# [Pipeline] . (step 2 of 2) Processing ridgeclassifiercv, total=  11.7s
# 0.9913544668587896
# 0.991333267611507
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      3987
#            1       0.99      0.95      0.97       603
#            2       0.99      0.99      0.99       710
#            3       1.00      0.99      1.00       599
#            4       1.00      1.00      1.00       601
#            5       0.99      0.99      0.99       605
#            6       0.99      0.99      0.99       627
#            7       0.99      0.99      0.99       628
#            8       0.99      0.99      0.99       617
#            9       1.00      1.00      1.00       619
#           10       1.00      1.00      1.00       536
#           11       0.98      0.99      0.99       625
#
#     accuracy                           0.99     10757
#    macro avg       0.99      0.99      0.99     10757
# weighted avg       0.99      0.99      0.99     10757
#
#  fold 2 is Finished!
# [Pipeline] ............ (step 1 of 2) Processing rocket, total=  11.3s
# [Pipeline] . (step 2 of 2) Processing ridgeclassifiercv, total=  11.8s
# 0.9923770568002231
# 0.9923555221213507
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      3927
#            1       1.00      0.96      0.98       634
#            2       1.00      0.99      1.00       681
#            3       1.00      1.00      1.00       613
#            4       1.00      1.00      1.00       622
#            5       0.98      0.99      0.99       615
#            6       0.99      1.00      0.99       617
#            7       0.99      0.99      0.99       627
#            8       1.00      0.99      0.99       634
#            9       1.00      1.00      1.00       636
#           10       0.99      1.00      1.00       525
#           11       0.99      0.98      0.98       626
#
#     accuracy                           0.99     10757
#    macro avg       0.99      0.99      0.99     10757
# weighted avg       0.99      0.99      0.99     10757
#
#  fold 3 is Finished!
# [Pipeline] ............ (step 1 of 2) Processing rocket, total=  11.2s
# [Pipeline] . (step 2 of 2) Processing ridgeclassifiercv, total=  11.7s
# 0.9927489076880172
# 0.9927290862744331
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      3887
#            1       0.99      0.96      0.97       628
#            2       0.99      0.99      0.99       700
#            3       1.00      1.00      1.00       610
#            4       1.00      1.00      1.00       602
#            5       0.98      0.99      0.98       615
#            6       0.99      1.00      1.00       642
#            7       0.99      1.00      0.99       632
#            8       1.00      0.99      0.99       574
#            9       1.00      1.00      1.00       632
#           10       1.00      0.99      1.00       581
#           11       0.99      0.99      0.99       654
#
#     accuracy                           0.99     10757
#    macro avg       0.99      0.99      0.99     10757
# weighted avg       0.99      0.99      0.99     10757
#
#  fold 4 is Finished!
# [Pipeline] ............ (step 1 of 2) Processing rocket, total=  11.1s
# [Pipeline] . (step 2 of 2) Processing ridgeclassifiercv, total=  11.6s
# 0.9918192804685321
# 0.9917881297591332
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      3908
#            1       1.00      0.95      0.97       657
#            2       0.99      0.98      0.99       659
#            3       1.00      1.00      1.00       625
#            4       1.00      1.00      1.00       638
#            5       0.98      0.99      0.99       623
#            6       0.98      1.00      0.99       598
#            7       1.00      1.00      1.00       616
#            8       1.00      1.00      1.00       661
#            9       1.00      1.00      1.00       594
#           10       0.99      1.00      1.00       525
#           11       0.99      0.99      0.99       653
#
#     accuracy                           0.99     10757
#    macro avg       0.99      0.99      0.99     10757
# weighted avg       0.99      0.99      0.99     10757
#
#  fold 5 is Finished!
#  Finished!
# Total time elapsed: 129.3363s
