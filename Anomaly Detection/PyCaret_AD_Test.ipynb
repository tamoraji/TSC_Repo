# %%
#pip install pycaret

# %%
import pandas as pd
import plotly.express as px
from pycaret.anomaly import *

# %%
data = pd.read_csv('https://raw.githubusercontent.com/numenta/NAB/master/data/realKnownCause/nyc_taxi.csv')
data['timestamp'] = pd.to_datetime(data['timestamp'])
data.head()
# Out:
#             timestamp  value
# 0 2014-07-01 00:00:00  10844
# 1 2014-07-01 00:30:00   8127
# 2 2014-07-01 01:00:00   6210
# 3 2014-07-01 01:30:00   4656
# 4 2014-07-01 02:00:00   3820

# %%
# create moving-averages
data['MA48'] = data['value'].rolling(48).mean()
data['MA336'] = data['value'].rolling(336).mean()

# %%
len(data['MA48']),len(data['MA336'])
# Out:
# (10320, 10320)

# %%
data['MA48']
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#              ...
# 10315    18715.645833
# 10316    18694.437500
# 10317    18703.500000
# 10318    18696.479167
# 10319    18702.479167
# Name: MA48, Length: 10320, dtype: float64

# %%
# Ensure all columns have the same length
length = len(data['timestamp'])
data = data[:length]

# %%
# Create the line plot
fig = px.line(data, x="timestamp", y=['value', 'MA48', 'MA336'], title='NYC Taxi Trips', template='plotly_dark')
fig.show()
# Out:
# <div>                            <div id="f3c79436-5829-4506-8bbc-273d7069e56c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3c79436-5829-4506-8bbc-273d7069e56c")) {                    Plotly.newPlot(                        "f3c79436-5829-4506-8bbc-273d7069e56c",                        [{"hovertemplate":"variable=value<br>timestamp=%{x}<br>_value=%{y}<extra></extra>","legendgroup":"value","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"value","showlegend":true,"x":["2014-07-01T00:00:00","2014-07-01T00:30:00","2014-07-01T01:00:00","2014-07-01T01:30:00","2014-07-01T02:00:00","2014-07-01T02:30:00","2014-07-01T03:00:00","2014-07-01T03:30:00","2014-07-01T04:00:00","2014-07-01T04:30:00","2014-07-01T05:00:00","2014-07-01T05:30:00","2014-07-01T06:00:00","2014-07-01T06:30:00","2014-07-01T07:00:00","2014-07-01T07:30:00","2014-07-01T08:00:00","2014-07-01T08:30:00","2014-07-01T09:00:00","2014-07-01T09:30:00","2014-07-01T10:00:00","2014-07-01T10:30:00","2014-07-01T11:00:00","2014-07-01T11:30:00","2014-07-01T12:00:00","2014-07-01T12:30:00","2014-07-01T13:00:00","2014-07-01T13:30:00","2014-07-01T14:00:00","2014-07-01T14:30:00","2014-07-01T15:00:00","2014-07-01T15:30:00","2014-07-01T16:00:00","2014-07-01T16:30:00","2014-07-01T17:00:00","2014-07-01T17:30:00","2014-07-01T18:00:00","2014-07-01T18:30:00","2014-07-01T19:00:00","2014-07-01T19:30:00","2014-07-01T20:00:00","2014-07-01T20:30:00","2014-07-01T21:00:00","2014-07-01T21:30:00","2014-07-01T22:00:00","2014-07-01T22:30:00","2014-07-01T23:00:00","2014-07-01T23:30:00","2014-07-02T00:00:00","2014-07-02T00:30:00","2014-07-02T01:00:00","2014-07-02T01:30:00","2014-07-02T02:00:00","2014-07-02T02:30:00","2014-07-02T03:00:00","2014-07-02T03:30:00","2014-07-02T04:00:00","2014-07-02T04:30:00","2014-07-02T05:00:00","2014-07-02T05:30:00","2014-07-02T06:00:00","2014-07-02T06:30:00","2014-07-02T07:00:00","2014-07-02T07:30:00","2014-07-02T08:00:00","2014-07-02T08:30:00","2014-07-02T09:00:00","2014-07-02T09:30:00","2014-07-02T10:00:00","2014-07-02T10:30:00","2014-07-02T11:00:00","2014-07-02T11:30:00","2014-07-02T12:00:00","2014-07-02T12:30:00","2014-07-02T13:00:00","2014-07-02T13:30:00","2014-07-02T14:00:00","2014-07-02T14:30:00","2014-07-02T15:00:00","2014-07-02T15:30:00","2014-07-02T16:00:00","2014-07-02T16:30:00","2014-07-02T17:00:00","2014-07-02T17:30:00","2014-07-02T18:00:00","2014-07-02T18:30:00","2014-07-02T19:00:00","2014-07-02T19:30:00","2014-07-02T20:00:00","2014-07-02T20:30:00","2014-07-02T21:00:00","2014-07-02T21:30:00","2014-07-02T22:00:00","2014-07-02T22:30:00","2014-07-02T23:00:00","2014-07-02T23:30:00","2014-07-03T00:00:00","2014-07-03T00:30:00","2014-07-03T01:00:00","2014-07-03T01:30:00","2014-07-03T02:00:00","2014-07-03T02:30:00","2014-07-03T03:00:00","2014-07-03T03:30:00","2014-07-03T04:00:00","2014-07-03T04:30:00","2014-07-03T05:00:00","2014-07-03T05:30:00","2014-07-03T06:00:00","2014-07-03T06:30:00","2014-07-03T07:00:00","2014-07-03T07:30:00","2014-07-03T08:00:00","2014-07-03T08:30:00","2014-07-03T09:00:00","2014-07-03T09:30:00","2014-07-03T10:00:00","2014-07-03T10:30:00","2014-07-03T11:00:00","2014-07-03T11:30:00","2014-07-03T12:00:00","2014-07-03T12:30:00","2014-07-03T13:00:00","2014-07-03T13:30:00","2014-07-03T14:00:00","2014-07-03T14:30:00","2014-07-03T15:00:00","2014-07-03T15:30:00","2014-07-03T16:00:00","2014-07-03T16:30:00","2014-07-03T17:00:00","2014-07-03T17:30:00","2014-07-03T18:00:00","2014-07-03T18:30:00","2014-07-03T19:00:00","2014-07-03T19:30:00","2014-07-03T20:00:00","2014-07-03T20:30:00","2014-07-03T21:00:00","2014-07-03T21:30:00","2014-07-03T22:00:00","2014-07-03T22:30:00","2014-07-03T23:00:00","2014-07-03T23:30:00","2014-07-04T00:00:00","2014-07-04T00:30:00","2014-07-04T01:00:00","2014-0 ...

# %%
# drop moving-average columns
data.drop(['MA48', 'MA336'], axis=1, inplace=True)
data
# Out:
#                 timestamp  value
# 0     2014-07-01 00:00:00  10844
# 1     2014-07-01 00:30:00   8127
# 2     2014-07-01 01:00:00   6210
# 3     2014-07-01 01:30:00   4656
# 4     2014-07-01 02:00:00   3820
# ...                   ...    ...
# 10315 2015-01-31 21:30:00  24670
# 10316 2015-01-31 22:00:00  25721
# 10317 2015-01-31 22:30:00  27309
# 10318 2015-01-31 23:00:00  26591
# 10319 2015-01-31 23:30:00  26288
#
# [10320 rows x 2 columns]

# %%
# set timestamp to index
data.set_index('timestamp', drop=True, inplace=True)
data.head()
# Out:
#                      value
# timestamp
# 2014-07-01 00:00:00  10844
# 2014-07-01 00:30:00   8127
# 2014-07-01 01:00:00   6210
# 2014-07-01 01:30:00   4656
# 2014-07-01 02:00:00   3820

# %%
# Slice the DataFrame for instances after a specific time
specific_time = pd.Timestamp('2015-01-01')
data = data.loc[specific_time:]

# %%
# resample timeseries to hourly 
data = data.resample('H').sum()
data
# Out:
#                      value
# timestamp
# 2015-01-01 00:00:00  51700
# 2015-01-01 01:00:00  58584
# 2015-01-01 02:00:00  51507
# 2015-01-01 03:00:00  44134
# 2015-01-01 04:00:00  30799
# ...                    ...
# 2015-01-31 19:00:00  56577
# 2015-01-31 20:00:00  48276
# 2015-01-31 21:00:00  48389
# 2015-01-31 22:00:00  53030
# 2015-01-31 23:00:00  52879
#
# [744 rows x 1 columns]

# %%
# creature features from date
data['day'] = [i.day for i in data.index]
data['day_name'] = [i.day_name() for i in data.index]
data['day_of_year'] = [i.dayofyear for i in data.index]
data['week_of_year'] = [i.weekofyear for i in data.index]
data['hour'] = [i.hour for i in data.index]
data['is_weekday'] = [i.isoweekday() for i in data.index]
data.head()
# Out:
#                      value  day  day_name  day_of_year  week_of_year  hour  \
# timestamp
# 2015-01-01 00:00:00  51700    1  Thursday            1             1     0
# 2015-01-01 01:00:00  58584    1  Thursday            1             1     1
# 2015-01-01 02:00:00  51507    1  Thursday            1             1     2
# 2015-01-01 03:00:00  44134    1  Thursday            1             1     3
# 2015-01-01 04:00:00  30799    1  Thursday            1             1     4
#
#                      is_weekday
# timestamp
# 2015-01-01 00:00:00           4
# 2015-01-01 01:00:00           4
# 2015-01-01 02:00:00           4
# 2015-01-01 03:00:00           4
# 2015-01-01 04:00:00           4

# %%
# init setup
s = setup(data, session_id = 123)
# Out:
# <style type="text/css">
# #T_e3cbe_row5_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e3cbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3cbe_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e3cbe_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3cbe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e3cbe_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e3cbe_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_e3cbe_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e3cbe_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_e3cbe_row1_col1" class="data row1 col1" >(744, 7)</td>
#     </tr>
#     <tr>
#       <th id="T_e3cbe_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e3cbe_row2_col0" class="data row2 col0" >Transformed data shape</td>
#       <td id="T_e3cbe_row2_col1" class="data row2 col1" >(744, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_e3cbe_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e3cbe_row3_col0" class="data row3 col0" >Numeric features</td>
#       <td id="T_e3cbe_row3_col1" class="data row3 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e3cbe_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e3cbe_row4_col0" class="data row4 col0" >Categorical features</td>
#       <td id="T_e3cbe_row4_col1" class="data row4 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e3cbe_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e3cbe_row5_col0" class="data row5 col0" >Preprocess</td>
#       <td id="T_e3cbe_row5_col1" class="data row5 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e3cbe_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e3cbe_row6_col0" class="data row6 col0" >Imputation type</td>
#       <td id="T_e3cbe_row6_col1" class="data row6 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e3cbe_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e3cbe_row7_col0" class="data row7 col0" >Numeric imputation</td>
#       <td id="T_e3cbe_row7_col1" class="data row7 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e3cbe_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e3cbe_row8_col0" class="data row8 col0" >Categorical imputation</td>
#       <td id="T_e3cbe_row8_col1" class="data row8 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e3cbe_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e3cbe_row9_col0" class="data row9 col0" >Maximum one-hot encoding</td>
#       <td id="T_e3cbe_row9_col1" class="data row9 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e3cbe_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e3cbe_row10_col0" class="data row10 col0" >Encoding method</td>
#       <td id="T_e3cbe_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e3cbe_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e3cbe_row11_col0" class="data row11 col0" >CPU Jobs</td>
#       <td id="T_e3cbe_row11_col1" class="data row11 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e3cbe_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e3cbe_row12_col0" class="data row12 col0" >Use GPU</td>
#       <td id="T_e3cbe_row12_col1" class="data row12 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3cbe_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e3cbe_row13_col0" class="data row13 col0" >Log Experiment</td>
#       <td id="T_e3cbe_row13_col1" class="data row13 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e3cbe_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e3cbe_row14_col0" class="data row14 col0" >Experiment Name</td>
#       <td id="T_e3cbe_row14_col1" class="data row14 col1" >anomaly-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_e3cbe_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e3cbe_row15_col0" class="data row15 col0" >USI</td>
#       <td id="T_e3cbe_row15_col1" class="data row15 col1" >b6bf</td>
#     </tr>
#   </tbody>
# </table>

# %%
# check list of available models
models()
# Out:
#                                         Name                    Reference
# ID
# abod            Angle-base Outlier Detection        pyod.models.abod.ABOD
# cluster       Clustering-Based Local Outlier      pyod.models.cblof.CBLOF
# cof         Connectivity-Based Local Outlier          pyod.models.cof.COF
# iforest                     Isolation Forest  pyod.models.iforest.IForest
# histogram  Histogram-based Outlier Detection        pyod.models.hbos.HBOS
# knn             K-Nearest Neighbors Detector          pyod.models.knn.KNN
# lof                     Local Outlier Factor          pyod.models.lof.LOF
# svm                   One-class SVM detector      pyod.models.ocsvm.OCSVM
# pca             Principal Component Analysis          pyod.models.pca.PCA
# mcd           Minimum Covariance Determinant          pyod.models.mcd.MCD
# sod               Subspace Outlier Detection          pyod.models.sod.SOD
# sos             Stochastic Outlier Selection          pyod.models.sos.SOS

# %%
# train model
iforest = create_model('iforest', fraction = 0.1)
iforest_results = assign_model(iforest)
iforest_results
# Out:
#                      value  day  day_name  day_of_year  week_of_year  hour  \
# timestamp
# 2015-01-01 00:00:00  51700    1  Thursday            1             1     0
# 2015-01-01 01:00:00  58584    1  Thursday            1             1     1
# 2015-01-01 02:00:00  51507    1  Thursday            1             1     2
# 2015-01-01 03:00:00  44134    1  Thursday            1             1     3
# 2015-01-01 04:00:00  30799    1  Thursday            1             1     4
# ...                    ...  ...       ...          ...           ...   ...
# 2015-01-31 19:00:00  56577   31  Saturday           31             5    19
# 2015-01-31 20:00:00  48276   31  Saturday           31             5    20
# 2015-01-31 21:00:00  48389   31  Saturday           31             5    21
# 2015-01-31 22:00:00  53030   31  Saturday           31             5    22
# 2015-01-31 23:00:00  52879   31  Saturday           31             5    23
#
#                      is_weekday  Anomaly  Anomaly_Score
# timestamp
# 2015-01-01 00:00:00           4        1       0.023103
# 2015-01-01 01:00:00           4        1       0.022519
# 2015-01-01 02:00:00           4        1       0.012140
# 2015-01-01 03:00:00           4        0      -0.001748
# 2015-01-01 04:00:00           4        0      -0.020535
# ...                         ...      ...            ...
# 2015-01-31 19:00:00           6        1       0.008566
# 2015-01-31 20:00:00           6        0      -0.006207
# 2015-01-31 21:00:00           6        0      -0.002989
# 2015-01-31 22:00:00           6        1       0.014720
# 2015-01-31 23:00:00           6        1       0.019574
#
# [744 rows x 9 columns]

# %%
# check anomalies
iforest_results[iforest_results['Anomaly'] == 1]
# Out:
#                      value  day  day_name  day_of_year  week_of_year  hour  \
# timestamp
# 2015-01-01 00:00:00  51700    1  Thursday            1             1     0
# 2015-01-01 01:00:00  58584    1  Thursday            1             1     1
# 2015-01-01 02:00:00  51507    1  Thursday            1             1     2
# 2015-01-01 23:00:00  20620    1  Thursday            1             1    23
# 2015-01-02 03:00:00   5090    2    Friday            2             1     3
# ...                    ...  ...       ...          ...           ...   ...
# 2015-01-31 07:00:00  11852   31  Saturday           31             5     7
# 2015-01-31 18:00:00  53330   31  Saturday           31             5    18
# 2015-01-31 19:00:00  56577   31  Saturday           31             5    19
# 2015-01-31 22:00:00  53030   31  Saturday           31             5    22
# 2015-01-31 23:00:00  52879   31  Saturday           31             5    23
#
#                      is_weekday  Anomaly  Anomaly_Score
# timestamp
# 2015-01-01 00:00:00           4        1       0.023103
# 2015-01-01 01:00:00           4        1       0.022519
# 2015-01-01 02:00:00           4        1       0.012140
# 2015-01-01 23:00:00           4        1       0.000070
# 2015-01-02 03:00:00           5        1       0.000168
# ...                         ...      ...            ...
# 2015-01-31 07:00:00           6        1       0.002077
# 2015-01-31 18:00:00           6        1       0.003226
# 2015-01-31 19:00:00           6        1       0.008566
# 2015-01-31 22:00:00           6        1       0.014720
# 2015-01-31 23:00:00           6        1       0.019574
#
# [75 rows x 9 columns]

# %%
import plotly.graph_objects as go
# plot value on y-axis and date on x-axis
fig = px.line(iforest_results, x=iforest_results.index, y="value", title='NYC TAXI TRIPS - UNSUPERVISED ANOMALY DETECTION', template = 'plotly_dark')
# create list of outlier_dates
outlier_dates = iforest_results[iforest_results['Anomaly'] == 1].index
# obtain y value of anomalies to plot
y_values = [iforest_results.loc[i]['value'] for i in outlier_dates]
fig.add_trace(go.Scatter(x=outlier_dates, y=y_values, mode = 'markers', 
                name = 'Anomaly', 
                marker=dict(color='red',size=10)))
        
fig.show()
# Out:
# <div>                            <div id="04dfb55c-2267-4966-816d-974712155606" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04dfb55c-2267-4966-816d-974712155606")) {                    Plotly.newPlot(                        "04dfb55c-2267-4966-816d-974712155606",                        [{"hovertemplate":"timestamp=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2015-01-01T00:00:00","2015-01-01T01:00:00","2015-01-01T02:00:00","2015-01-01T03:00:00","2015-01-01T04:00:00","2015-01-01T05:00:00","2015-01-01T06:00:00","2015-01-01T07:00:00","2015-01-01T08:00:00","2015-01-01T09:00:00","2015-01-01T10:00:00","2015-01-01T11:00:00","2015-01-01T12:00:00","2015-01-01T13:00:00","2015-01-01T14:00:00","2015-01-01T15:00:00","2015-01-01T16:00:00","2015-01-01T17:00:00","2015-01-01T18:00:00","2015-01-01T19:00:00","2015-01-01T20:00:00","2015-01-01T21:00:00","2015-01-01T22:00:00","2015-01-01T23:00:00","2015-01-02T00:00:00","2015-01-02T01:00:00","2015-01-02T02:00:00","2015-01-02T03:00:00","2015-01-02T04:00:00","2015-01-02T05:00:00","2015-01-02T06:00:00","2015-01-02T07:00:00","2015-01-02T08:00:00","2015-01-02T09:00:00","2015-01-02T10:00:00","2015-01-02T11:00:00","2015-01-02T12:00:00","2015-01-02T13:00:00","2015-01-02T14:00:00","2015-01-02T15:00:00","2015-01-02T16:00:00","2015-01-02T17:00:00","2015-01-02T18:00:00","2015-01-02T19:00:00","2015-01-02T20:00:00","2015-01-02T21:00:00","2015-01-02T22:00:00","2015-01-02T23:00:00","2015-01-03T00:00:00","2015-01-03T01:00:00","2015-01-03T02:00:00","2015-01-03T03:00:00","2015-01-03T04:00:00","2015-01-03T05:00:00","2015-01-03T06:00:00","2015-01-03T07:00:00","2015-01-03T08:00:00","2015-01-03T09:00:00","2015-01-03T10:00:00","2015-01-03T11:00:00","2015-01-03T12:00:00","2015-01-03T13:00:00","2015-01-03T14:00:00","2015-01-03T15:00:00","2015-01-03T16:00:00","2015-01-03T17:00:00","2015-01-03T18:00:00","2015-01-03T19:00:00","2015-01-03T20:00:00","2015-01-03T21:00:00","2015-01-03T22:00:00","2015-01-03T23:00:00","2015-01-04T00:00:00","2015-01-04T01:00:00","2015-01-04T02:00:00","2015-01-04T03:00:00","2015-01-04T04:00:00","2015-01-04T05:00:00","2015-01-04T06:00:00","2015-01-04T07:00:00","2015-01-04T08:00:00","2015-01-04T09:00:00","2015-01-04T10:00:00","2015-01-04T11:00:00","2015-01-04T12:00:00","2015-01-04T13:00:00","2015-01-04T14:00:00","2015-01-04T15:00:00","2015-01-04T16:00:00","2015-01-04T17:00:00","2015-01-04T18:00:00","2015-01-04T19:00:00","2015-01-04T20:00:00","2015-01-04T21:00:00","2015-01-04T22:00:00","2015-01-04T23:00:00","2015-01-05T00:00:00","2015-01-05T01:00:00","2015-01-05T02:00:00","2015-01-05T03:00:00","2015-01-05T04:00:00","2015-01-05T05:00:00","2015-01-05T06:00:00","2015-01-05T07:00:00","2015-01-05T08:00:00","2015-01-05T09:00:00","2015-01-05T10:00:00","2015-01-05T11:00:00","2015-01-05T12:00:00","2015-01-05T13:00:00","2015-01-05T14:00:00","2015-01-05T15:00:00","2015-01-05T16:00:00","2015-01-05T17:00:00","2015-01-05T18:00:00","2015-01-05T19:00:00","2015-01-05T20:00:00","2015-01-05T21:00:00","2015-01-05T22:00:00","2015-01-05T23:00:00","2015-01-06T00:00:00","2015-01-06T01:00:00","2015-01-06T02:00:00","2015-01-06T03:00:00","2015-01-06T04:00:00","2015-01-06T05:00:00","2015-01-06T06:00:00","2015-01-06T07:00:00","2015-01-06T08:00:00","2015-01-06T09:00:00","2015-01-06T10:00:00","2015-01-06T11:00:00","2015-01-06T12:00:00","2015-01-06T13:00:00","2015-01-06T14:00:00","2015-01-06T15:00:00","2015-01-06T16:00:00","2015-01-06T17:00:00","2015-01-06T18:00:00","2015-01-06T19:00:00","2015-01-06T20:00:00","2015-01-06T21:00:00","2015-01-06T22:00:00","2015-01-06T23:00:00","2015-01-07T00:00:00","2015-01-07T01:00:00","2015-01-07T02:00:00","2015-01-07T03:00 ...

# %%
import time
from datetime import datetime

# Get the current time in seconds since the epoch
current_time = time.time()

# %%
# Convert the time to a datetime object
datetime_obj = datetime.fromtimestamp(current_time).strftime('%Y-%m-%d %H:%M:%S')

# %%
datetime_obj
# Out:
# '2023-06-05 09:58:24'

# %%
# Format the datetime object as a string
formatted_time = datetime_obj.strftime('%Y-%m-%d %H:%M:%S')

print(formatted_time)
