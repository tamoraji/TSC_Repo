# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.model_selection import cross_val_predict, KFold
import sklearn
import numpy as np
import os
import sys
import time

# %%
# define a list of datasets
datasets = [
"Control_charts",
"ETCHING_Multivar",
"Hydraulic_systems_10HZ_Multivar",
"Hydraulic_systems_100HZ_Multivar",
"Gas_sensors_home_activity",
"PHM2022_Multivar",
"PHM2022_Univar_PIN",
"PHM2022_Univar_PO",
"PHM2022_Univar_PDIN",
"CWRU_12k_DE_univar",
"CWRU_12k_DE_multivar",
"CWRU_12k_FE_univar",
"CWRU_12k_FE_multivar",
"CWRU_48k_DE_univar",
"CWRU_48k_DE_multivar",
"MFPT_48KHZ_Univar",
"MFPT_96KHZ_Univar",
"PADERBORN_64KHZ_Univar",
"PADERBORN_4KHZ_Univar",
"PADERBORN_64KHZ_Multivar",
"PADERBORN_4KHZ_Multivar",
"BEARING_Univar",
]


datasets_path = "../datasets"
print(f"We are going to work on {len(datasets)} datasets!")

for dataset in datasets:
    Dataset_name = dataset + "_Dataset"
    Dataset = np.load(datasets_path + "/" + Dataset_name + ".npy", mmap_mode='r')
    print(Dataset.shape)
    

    Labels_name = dataset + "_Labels"
    Labels = np.load(datasets_path + "/"  + Labels_name + ".npy", mmap_mode='r')
# Out:
# We are going to work on 22 datasets!
# (600, 60, 1)
# (128, 112, 18)
# (2205, 600, 17)
# (2205, 6000, 7)
# (99, 15393, 10)
# (53785, 749, 3)
# (53785, 749, 1)
# (53785, 749, 1)
# (53785, 749, 1)
# (7200, 1000, 1)
# (6240, 1000, 3)
# (5400, 1000, 1)
# (5400, 1000, 3)
# (10681, 2000, 1)
# (10681, 2000, 2)
# (1898, 2000, 1)
# (1898, 4000, 1)
# (192477, 3000, 1)
# (185520, 200, 1)
# (192477, 3000, 3)
# (185520, 200, 5)
# (2560, 8192, 1)

# %%
# change this directory for your machine
root_dir = './'


# define a list of algorithms
algorirhms_path = "./classifiers"

from classifiers import FBL_module


# define the number of folds
n_folds = 5

# perform cross-validation for each dataset and algorithm combination
for dataset in datasets:
    Dataset_name = dataset + "_Dataset"
    Dataset = np.load(datasets_path + "/" + Dataset_name + ".npy", mmap_mode='r')
    start = time.time() ##Start timing
    print(f"Starting to work on {Dataset_name} at {start}")
    print(f"The shape of the dataset is:{Dataset.shape}")
    

    Labels_name = dataset + "_Labels"
    Labels = np.load(datasets_path + "/"  + Labels_name + ".npy", mmap_mode='r')

    # Create a folder for results
    results_path = root_dir + "Results/" + Dataset_name
    if os.path.exists(results_path):
        pass
    else:
        try:
            os.makedirs(results_path)
        except:
            # in case another machine created the path meanwhile !:(
            pass



    #Run The FBL Module
    FBL_module.FBL(results_path, dataset_name= Dataset_name, dataset = Dataset, labels = Labels, nb_folds=n_folds)
    print(f"Working on {Dataset_name} finished successfully!")
# Out:
# Starting to work on Control_charts_Dataset at 1682968878.8977933
# The shape of the dataset is:(600, 60, 1)
#
#  The dataset shape is:(600, 60, 1)
#
#  The number of data samples (N) is:600
#
#  The number of TS length (T) is:60
#
#  The number of TS dimention (M) is:1
# The new shape of the dataset is : (36000, 3)
# Feature Extraction: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:01<00:00, 28.03it/s]
# The shape of the extracted features is : (600, 777)
# (480,)
# (120,)
# 776
# Selected features: {'feature_0__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"max"'}
# Classification rate: 0.7708333333333334
# 775
# Selected features: {'feature_0__autocorrelation__lag_5', 'feature_0__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"max"'}
# Classification rate: 0.9291666666666667
# 774
# Selected features: {'feature_0__autocorrelation__lag_5', 'feature_0__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"max"', 'feature_0__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"min"'}
# Classification rate: 0.98125
# 773
# Selected features: {'feature_0__autocorrelation__lag_5', 'feature_0__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"max"', 'feature_0__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"min"', 'feature_0__index_mass_quantile__q_0.6'}
# Classification rate: 0.9875
# 772
# Selected features: {'feature_0__autocorrelation__lag_5', 'feature_0__index_mass_quantile__q_0.3', 'feature_0__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"max"', 'feature_0__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"min"', 'feature_0__index_mass_quantile__q_0.6'}
# Classification rate: 0.9958333333333333
# 771
# Selected features: {'feature_0__autocorrelation__lag_5', 'feature_0__c3__lag_3', 'feature_0__index_mass_quantile__q_0.3', 'feature_0__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"max"', 'feature_0__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"min"', 'feature_0__index_mass_quantile__q_0.6'}
# Classification rate: 0.9979166666666667
# 0.975
# 0.9748467432950192
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        20
#            1       1.00      1.00      1.00        24
#            2       0.91      0.95      0.93        22
#            3       1.00      1.00      1.00        21
#            4       0.93      0.87      0.90        15
#            5       1.00      1.00      1.00        18
#
#     accuracy                           0.97       120
#    macro avg       0.97      0.97      0.97       120
# weighted avg       0.98      0.97      0.97       120
#
#  fold 1 is Finished!
# (480,)
# (120,)
# 776
# Selected features: {'feature_0__linear_trend__attr_"intercept"'}
# Classification rate: 0.7416666666666667
# 775
# Selected features: {'feature_0__autocorrelation__lag_6', 'feature_0__linear_trend__attr_"intercept"'}
# Classification rate: 0.95625
# 774
# Selected features: {'feature_0__autocorrelation__lag_6', 'feature_0__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"max"', 'feature_0__linear_trend__attr_"intercept"'}
# Classification rate: 0.9895833333333334
# 773
# Selected features: {'feature_0__autocorrelation__lag_6', 'feature_0__agg_linear_trend__attr_"rvalue"__chunk_len_5__f_agg_"max"', 'feature_0__linear_trend__attr_"intercept"', 'feature_0__agg_linear_trend__attr_"stderr"__chunk_len_10__f_agg_"mean"'}
# Classification rate: 0.9979166666666667
# 0.975
# 0.9749870264660093
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95        20
#            1       0.94      1.00      0.97        17
#            2       1.00      1.00      1.00        21
#            3       1.00      0.94      0.97        18
#            4       1.00      0.95      0.98        21
#            5       0.96      1.00      0.98        23
#
#     accuracy                           0.97       120
#    macro avg       0.98      0.97      0.97       120
# weighted avg       0.98      0.97      0.97       120
#
#  fold 2 is Finished!
# (480,)
# (120,)
# 776
# Selected features: {'feature_0__cwt_coefficients__coeff_0__w_20__widths_(2, 5, 10, 20)'}
# Classification rate: 0.7229166666666667
# 775
# Selected features: {'feature_0__cwt_coefficients__coeff_0__w_20__widths_(2, 5, 10, 20)', 'feature_0__spkt_welch_density__coeff_2'}
# Classification rate: 0.9083333333333333
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_244994/2361685166.py in <module>
#      38
#      39     #Run The FBL Module
# ---> 40     FBL_module.FBL(results_path, dataset_name= Dataset_name, dataset = Dataset, labels = Labels, nb_folds=n_folds)
#      41     print(f"Working on {Dataset_name} finished successfully!")
#      42
#
# ~/Moji/TSC_Repo/classifiers/FBL_module.py in FBL(results_path, dataset_name, dataset, labels, nb_folds)
#      83                 feature_set = selected_features.union({feature})
#      84                 X_train_selected = X_train[list(feature_set)]
# ---> 85                 classifier.fit(X_train_selected, y_train)
#      86                 score = classifier.score(X_train_selected, y_train)
#      87                 candidate_scores.append((feature, score))
#
# ~/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py in fit(self, X, y, sample_weight)
#    1289             n_threads = 1
#    1290
# -> 1291         fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#    1292             path_func(
#    1293                 X,
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      61             for delayed_func, args, kwargs in iterable
#      62         )
# ---> 63         return super().__call__(iterable_with_config)
#      64
#      65
#
# ~/.local/lib/python3.10/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1083             # remaining jobs.
#    1084             self._iterating = False
# -> 1085             if self.dispatch_one_batch(iterator):
#    1086                 self._iterating = self._original_iterator is not None
#    1087
#
# ~/.local/lib/python3.10/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     899                 return False
#     900             else:
# --> 901                 self._dispatch(tasks)
#     902                 return True
#     903
#
# ~/.local/lib/python3.10/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     817         with self._lock:
#     818             job_idx = len(self._jobs)
# --> 819             job = self._backend.apply_async(batch, callback=cb)
#     820             # A job can complete so quickly than its callback is
#     821             # called before we get here, causing self._jobs to
#
# ~/.local/lib/python3.10/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/.local/lib/python3.10/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     595         # Don't delay the application, to avoid keeping the input
#     596         # arguments in memory
# --> 597         self.results = batch()
#     598
#     599     def get(self):
#
# ~/.local/lib/python3.10/site-packages/joblib/parallel.py in __call__(self)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~/.local/lib/python3.10/site-packages/joblib/parallel.py in <listcomp>(.0)
#     286         # change the default number of processes to -1
#     287         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288             return [func(*args, **kwargs)
#     289                     for func, args, kwargs in self.items]
#     290
#
# ~/.local/lib/python3.10/site-packages/sklearn/utils/parallel.py in __call__(self, *args, **kwargs)
#     121             config = {}
#     122         with config_context(**config):
# --> 123             return self.function(*args, **kwargs)
#
# ~/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py in _logistic_regression_path(X, y, pos_class, Cs, fit_intercept, max_iter, tol, verbose, solver, coef, class_weight, dual, penalty, intercept_scaling, multi_class, random_state, check_input, max_squared_sum, sample_weight, l1_ratio, n_threads)
#     448                 np.searchsorted(np.array([0, 1, 2, 3]), verbose)
#     449             ]
# --> 450             opt_res = optimize.minimize(
#     451                 func,
#     452                 w0,
#
# /usr/lib/python3/dist-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     679                                  **options)
#     680     elif meth == 'l-bfgs-b':
# --> 681         res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     682                                callback=callback, **options)
#     683     elif meth == 'tnc':
#
# /usr/lib/python3/dist-packages/scipy/optimize/_lbfgsb_py.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     360             # until the completion of the current minimization iteration.
#     361             # Overwrite f and g:
# --> 362             f, g = func_and_grad(x)
#     363         elif task_str.startswith(b'NEW_X'):
#     364             # new iteration
#
# /usr/lib/python3/dist-packages/scipy/optimize/_differentiable_functions.py in fun_and_grad(self, x)
#     283         if not np.array_equal(x, self.x):
#     284             self._update_x_impl(x)
# --> 285         self._update_fun()
#     286         self._update_grad()
#     287         return self.f, self.g
#
# /usr/lib/python3/dist-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     249     def _update_fun(self):
#     250         if not self.f_updated:
# --> 251             self._update_fun_impl()
#     252             self.f_updated = True
#     253
#
# /usr/lib/python3/dist-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#     153
#     154         def update_fun():
# --> 155             self.f = fun_wrapped(self.x)
#     156
#     157         self._update_fun_impl = update_fun
#
# /usr/lib/python3/dist-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#     135             # Overwriting results in undefined behaviour because
#     136             # fun(self.x) will change self.x, with the two no longer linked.
# --> 137             fx = fun(np.copy(x), *args)
#     138             # Make sure the function returns a true scalar
#     139             if not np.isscalar(fx):
#
# /usr/lib/python3/dist-packages/scipy/optimize/_optimize.py in __call__(self, x, *args)
#      74     def __call__(self, x, *args):
#      75         """ returns the the function value """
# ---> 76         self._compute_if_needed(x, *args)
#      77         return self._value
#      78
#
# /usr/lib/python3/dist-packages/scipy/optimize/_optimize.py in _compute_if_needed(self, x, *args)
#      68         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      69             self.x = np.asarray(x).copy()
# ---> 70             fg = self.fun(x, *args)
#      71             self.jac = fg[1]
#      72             self._value = fg[0]
#
# ~/.local/lib/python3.10/site-packages/sklearn/linear_model/_linear_loss.py in loss_gradient(self, coef, X, y, sample_weight, l2_reg_strength, n_threads, raw_prediction)
#     276             weights, intercept = self.weight_intercept(coef)
#     277
# --> 278         loss, grad_pointwise = self.base_loss.loss_gradient(
#     279             y_true=y,
#     280             raw_prediction=raw_prediction,
#
# ~/.local/lib/python3.10/site-packages/sklearn/_loss/loss.py in loss_gradient(self, y_true, raw_prediction, sample_weight, loss_out, gradient_out, n_threads)
#     255         if sample_weight is not None:
#     256             sample_weight = ReadonlyArrayWrapper(sample_weight)
# --> 257         return self.closs.loss_gradient(
#     258             y_true=y_true,
#     259             raw_prediction=raw_prediction,
#
# KeyboardInterrupt:
