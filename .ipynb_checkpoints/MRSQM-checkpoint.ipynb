# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.model_selection import cross_val_predict, KFold
import sklearn
import numpy as np
import os
import sys
import time

# %%
# define a list of datasets
datasets = [
"Control_charts",
"ETCHING_Multivar",
"Hydraulic_systems_10HZ_Multivar",
"Hydraulic_systems_100HZ_Multivar",
"Gas_sensors_home_activity",
# "PHM2022_Multivar",
# "PHM2022_Univar_PIN",
# "PHM2022_Univar_PO",
# "PHM2022_Univar_PDIN",
# "CWRU_12k_DE_univar",
# "CWRU_12k_DE_multivar",
# "CWRU_12k_FE_univar",
# "CWRU_12k_FE_multivar",
# "CWRU_48k_DE_univar",
# "CWRU_48k_DE_multivar",
# "MFPT_48KHZ_Univar",
# "MFPT_96KHZ_Univar",
# "PADERBORN_64KHZ_Univar",
# "PADERBORN_4KHZ_Univar",
# "PADERBORN_64KHZ_Multivar",
# "PADERBORN_4KHZ_Multivar",
# "BEARING_Univar",
]

datasets_path = "../datasets"
print(f"We are going to work on {len(datasets)} datasets!")


for dataset in datasets:
    Dataset_name = dataset + "_Dataset"
    Dataset = np.load(datasets_path + "/" + Dataset_name + ".npy", mmap_mode='r')
    print(Dataset.shape)
    

    Labels_name = dataset + "_Labels"
    Labels = np.load(datasets_path + "/"  + Labels_name + ".npy", mmap_mode='r')
# Out:
# (600, 60, 1)
# (53785, 749, 3)
# (53785, 749, 1)

# %%
#pip install mrsqm
# Out:
# Collecting mrsqm
#   Downloading mrsqm-0.0.1-cp39-cp39-macosx_10_13_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 2.8 MB/s eta 0:00:0000:0100:01
# Installing collected packages: mrsqm
# Successfully installed mrsqm-0.0.1
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# change this directory for your machine
root_dir = './'


# define a list of algorithms
algorirhms_path = "./classifiers"

from classifiers import mrsqm_module


# define the number of folds
n_folds = 5

# perform cross-validation for each dataset and algorithm combination
for dataset in datasets:
    Dataset_name = dataset + "_Dataset"
    Dataset = np.load(datasets_path + "/" + Dataset_name + ".npy", mmap_mode='r')
    start = time.time() ##Start timing
    print(f"Starting to work on {Dataset_name} at {start}")
    print(f"The shape of the dataset is:{Dataset.shape}")
    

    Labels_name = dataset + "_Labels"
    Labels = np.load(datasets_path + "/"  + Labels_name + ".npy", mmap_mode='r')

    # Create a folder for results
    results_path = root_dir + "Results/" + Dataset_name
    if os.path.exists(results_path):
        pass
    else:
        try:
            os.makedirs(results_path)
        except:
            # in case another machine created the path meanwhile !:(
            pass



    #Run The MrSQM Module
    mrsqm_module.MRSQM(results_path, Dataset_name, Dataset, Labels, nb_folds=n_folds,
                        strat='RS',
                        features_per_rep=500, 
                        selection_per_rep=2000, 
                        nsax=1, 
                        nsfa=0)



    print(f"Working on {Dataset_name} finished successfully!")
# Out:
#  The dataset shape is:(600, 60, 1)
#
#  The number of data samples (N) is:600
#
#  The number of TS length (T) is:60
#
#  The number of TS dimention (M) is:1
#
#  The classifier is fitted
# 0.95
# 0.9501204337269618
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        16
#            1       1.00      1.00      1.00        18
#            2       0.96      0.96      0.96        25
#            3       0.86      1.00      0.92        18
#            4       1.00      0.90      0.95        21
#            5       1.00      0.86      0.93        22
#
#     accuracy                           0.95       120
#    macro avg       0.95      0.95      0.95       120
# weighted avg       0.96      0.95      0.95       120
#
#  fold 1 is Finished!
#
#  The classifier is fitted
# 0.9666666666666667
# 0.9666666666666667
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        26
#            1       1.00      1.00      1.00        19
#            2       0.96      0.96      0.96        23
#            3       0.93      0.93      0.93        14
#            4       0.95      0.95      0.95        20
#            5       0.94      0.94      0.94        18
#
#     accuracy                           0.97       120
#    macro avg       0.96      0.96      0.96       120
# weighted avg       0.97      0.97      0.97       120
#
#  fold 2 is Finished!
#
#  The classifier is fitted
# 0.925
# 0.9246932246129357
#               precision    recall  f1-score   support
#
#            0       0.89      1.00      0.94        25
#            1       1.00      1.00      1.00        17
#            2       0.88      0.94      0.91        16
#            3       0.88      0.83      0.86        18
#            4       1.00      0.88      0.94        25
#            5       0.89      0.89      0.89        19
#
#     accuracy                           0.93       120
#    macro avg       0.93      0.92      0.92       120
# weighted avg       0.93      0.93      0.92       120
#
#  fold 3 is Finished!
#
#  The classifier is fitted
# 0.9166666666666666
# 0.9164298664298663
#               precision    recall  f1-score   support
#
#            0       0.74      1.00      0.85        14
#            1       1.00      1.00      1.00        29
#            2       0.93      0.93      0.93        14
#            3       0.89      0.96      0.92        25
#            4       0.92      0.86      0.89        14
#            5       1.00      0.75      0.86        24
#
#     accuracy                           0.92       120
#    macro avg       0.91      0.92      0.91       120
# weighted avg       0.93      0.92      0.92       120
#
#  fold 4 is Finished!
#
#  The classifier is fitted
# 0.9583333333333334
# 0.9574747286906805
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97        19
#            1       1.00      1.00      1.00        17
#            2       0.92      1.00      0.96        22
#            3       0.93      1.00      0.96        25
#            4       1.00      0.90      0.95        20
#            5       1.00      0.82      0.90        17
#
#     accuracy                           0.96       120
#    macro avg       0.97      0.95      0.96       120
# weighted avg       0.96      0.96      0.96       120
#
#  fold 5 is Finished!
#  Finished!
# Total time elapsed: 20.8332s
#
#  The dataset shape is:(53785, 749, 3)
#
#  The number of data samples (N) is:53785
#
#  The number of TS length (T) is:749
#
#  The number of TS dimention (M) is:3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/mojtabaaskarzadeh/TSC_Repo/mrsqm.ipynb Cell 4 in <cell line: 15>()
#      <a href='vscode-notebook-cell:/Users/mojtabaaskarzadeh/TSC_Repo/mrsqm.ipynb#W2sZmlsZQ%3D%3D?line=31'>32</a>         pass
#      <a href='vscode-notebook-cell:/Users/mojtabaaskarzadeh/TSC_Repo/mrsqm.ipynb#W2sZmlsZQ%3D%3D?line=35'>36</a> #Run The MrSQM Module
# ---> <a href='vscode-notebook-cell:/Users/mojtabaaskarzadeh/TSC_Repo/mrsqm.ipynb#W2sZmlsZQ%3D%3D?line=36'>37</a> mrsqm_module.MRSQM(results_path, Dataset_name, Dataset, Labels, nb_folds=n_folds,
#      <a href='vscode-notebook-cell:/Users/mojtabaaskarzadeh/TSC_Repo/mrsqm.ipynb#W2sZmlsZQ%3D%3D?line=37'>38</a>                     strat='RS',
#      <a href='vscode-notebook-cell:/Users/mojtabaaskarzadeh/TSC_Repo/mrsqm.ipynb#W2sZmlsZQ%3D%3D?line=38'>39</a>                     features_per_rep=500,
#      <a href='vscode-notebook-cell:/Users/mojtabaaskarzadeh/TSC_Repo/mrsqm.ipynb#W2sZmlsZQ%3D%3D?line=39'>40</a>                     selection_per_rep=2000,
#      <a href='vscode-notebook-cell:/Users/mojtabaaskarzadeh/TSC_Repo/mrsqm.ipynb#W2sZmlsZQ%3D%3D?line=40'>41</a>                     nsax=1,
#      <a href='vscode-notebook-cell:/Users/mojtabaaskarzadeh/TSC_Repo/mrsqm.ipynb#W2sZmlsZQ%3D%3D?line=41'>42</a>                     nsfa=0)
#
# File ~/TSC_Repo/classifiers/mrsqm_module.py:79, in MRSQM(results_path, dataset_name, dataset, labels, nb_folds, strat, features_per_rep, selection_per_rep, nsax, nsfa)
#      75 y_train, y_test = labels[train_idx], labels[test_idx]
#      77 # fit the algorithm on the training data
# ---> 79 classifier.fit(X_train, y_train)
#      80 print("\n The classifier is fitted")
#      82 # make predictions on the testing data
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sktime/classification/base.py:175, in BaseClassifier.fit(self, X, y)
#     172 self._X_metadata = X_metadata
#     174 # Check this classifier can handle characteristics
# --> 175 self._check_capabilities(missing, multivariate, unequal)
#     177 # remember class labels
#     178 self.classes_ = np.unique(y)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sktime/classification/base.py:666, in BaseClassifier._check_capabilities(self, missing, multivariate, unequal)
#     664     warn(msg)
#     665 else:
# --> 666     raise ValueError(msg)
#
# ValueError: Data seen by MrSQM instance has multivariate series, but this MrSQM instance cannot handle multivariate series. Calls with multivariate series may result in error or unreliable results.
