# %%
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
from sklearn.model_selection import cross_val_predict, KFold
import sklearn
import numpy as np
import os
import sys
import time

# %%
# define a list of datasets
datasets = [
"Control_charts",
"ETCHING_Multivar",
"Hydraulic_systems_10HZ_Multivar",
"Hydraulic_systems_100HZ_Multivar",
# "Gas_sensors_home_activity",
# "PHM2022_Multivar",
# "PHM2022_Univar_PIN",
# "PHM2022_Univar_PO",
# "PHM2022_Univar_PDIN",
# "CWRU_12k_DE_univar",
# "CWRU_12k_DE_multivar",
# "CWRU_12k_FE_univar",
# "CWRU_12k_FE_multivar",
#"CWRU_48k_DE_univar",
#"CWRU_48k_DE_multivar",
#"MFPT_48KHZ_Univar",
#"MFPT_96KHZ_Univar",
# "BEARING_Univar",
#"PADERBORN_64KHZ_Univar",
# "PADERBORN_4KHZ_Univar",
# "PADERBORN_64KHZ_Multivar", #ran out of memory on DrCIF
"PADERBORN_4KHZ_Multivar",

]

datasets = ["Control_charts", "PHM2022_Multivar", "PHM2022_Univar_PDIN"]
datasets_path = "../datasets"
print(f"We are going to work on {len(datasets)} datasets!")


for dataset in datasets:
    Dataset_name = dataset + "_Dataset"
    Dataset = np.load(datasets_path + "/" + Dataset_name + ".npy", mmap_mode='r')
    print(Dataset.shape)
    

    Labels_name = dataset + "_Labels"
    Labels = np.load(datasets_path + "/"  + Labels_name + ".npy", mmap_mode='r')
# Out:
# (600, 60, 1)
# (53785, 749, 3)
# (53785, 749, 1)

# %%
# change this directory for your machine
root_dir = './'


# define a list of algorithms
algorirhms_path = "./classifiers"

from classifiers import STC_module


# define the number of folds
n_folds = 5

# perform cross-validation for each dataset and algorithm combination
for dataset in datasets:
    Dataset_name = dataset + "_Dataset"
    Dataset = np.load(datasets_path + "/" + Dataset_name + ".npy", mmap_mode='r')
    start = time.time() ##Start timing
    print(f"Starting to work on {Dataset_name} at {start}")
    print(f"The shape of the dataset is:{Dataset.shape}")
    

    Labels_name = dataset + "_Labels"
    Labels = np.load(datasets_path + "/"  + Labels_name + ".npy", mmap_mode='r')

    # Create a folder for results
    results_path = root_dir + "Results/" + Dataset_name
    if os.path.exists(results_path):
        pass
    else:
        try:
            os.makedirs(results_path)
        except:
            # in case another machine created the path meanwhile !:(
            pass



    #Run The STC Module
    STC_module.STC(results_path, Dataset_name, Dataset, Labels, nb_folds=n_folds,
                n_shapelet_samples= 10000, max_shapelets=1000, batch_size=100,
                n_jobs=10)
    
    print(f"Working on {Dataset_name} finished successfully!")
# Out:
#  The dataset shape is:(600, 60, 1)
#
#  The number of data samples (N) is:600
#
#  The number of TS length (T) is:60
#
#  The number of TS dimention (M) is:1
#
#  The classifier is fitted
# 0.9666666666666667
# 0.9665432797050444
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        18
#            1       1.00      1.00      1.00        21
#            2       1.00      0.90      0.95        21
#            3       1.00      0.89      0.94        18
#            4       0.93      1.00      0.96        25
#            5       0.89      1.00      0.94        17
#
#     accuracy                           0.97       120
#    macro avg       0.97      0.97      0.97       120
# weighted avg       0.97      0.97      0.97       120
#
#  fold 1 is Finished!
#
#  The classifier is fitted
# 0.9333333333333333
# 0.932908015756853
#               precision    recall  f1-score   support
#
#            0       1.00      0.87      0.93        23
#            1       0.93      1.00      0.96        25
#            2       0.94      0.94      0.94        16
#            3       0.87      0.87      0.87        15
#            4       0.94      1.00      0.97        16
#            5       0.92      0.92      0.92        25
#
#     accuracy                           0.93       120
#    macro avg       0.93      0.93      0.93       120
# weighted avg       0.94      0.93      0.93       120
#
#  fold 2 is Finished!
#
#  The classifier is fitted
# 0.9666666666666667
# 0.9665332059794545
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        13
#            1       0.96      1.00      0.98        23
#            2       1.00      0.89      0.94        19
#            3       0.96      1.00      0.98        27
#            4       0.90      1.00      0.95        18
#            5       1.00      0.95      0.97        20
#
#     accuracy                           0.97       120
#    macro avg       0.97      0.96      0.96       120
# weighted avg       0.97      0.97      0.97       120
#
#  fold 3 is Finished!
#
#  The classifier is fitted
# 0.925
# 0.9259296594982079
#               precision    recall  f1-score   support
#
#            0       1.00      0.80      0.89        25
#            1       0.72      1.00      0.84        13
#            2       1.00      0.90      0.95        21
#            3       1.00      0.89      0.94        19
#            4       0.92      1.00      0.96        23
#            5       0.90      1.00      0.95        19
#
#     accuracy                           0.93       120
#    macro avg       0.92      0.93      0.92       120
# weighted avg       0.94      0.93      0.93       120
#
#  fold 4 is Finished!
#
#  The classifier is fitted
# 0.9666666666666667
# 0.9666634129450274
#               precision    recall  f1-score   support
#
#            0       1.00      0.90      0.95        21
#            1       0.90      1.00      0.95        18
#            2       0.96      1.00      0.98        23
#            3       1.00      0.95      0.98        21
#            4       1.00      0.94      0.97        18
#            5       0.95      1.00      0.97        19
#
#     accuracy                           0.97       120
#    macro avg       0.97      0.97      0.97       120
# weighted avg       0.97      0.97      0.97       120
#
#  fold 5 is Finished!
#  Finished!
# Total time elapsed: 67.0757s
#
#  The dataset shape is:(53785, 749, 3)
#
#  The number of data samples (N) is:53785
#
#  The number of TS length (T) is:749
#
#  The number of TS dimention (M) is:3
# CBOSS is not capable of doing classification on MTS. so it will be done on only the first dimension
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/mojtabaaskarzadeh/TSC_Repo/CBOSS.ipynb Cell 3 in <cell line: 15>()
#      <a href='vscode-notebook-cell:/Users/mojtabaaskarzadeh/TSC_Repo/CBOSS.ipynb#W2sZmlsZQ%3D%3D?line=31'>32</a>         pass
#      <a href='vscode-notebook-cell:/Users/mojtabaaskarzadeh/TSC_Repo/CBOSS.ipynb#W2sZmlsZQ%3D%3D?line=35'>36</a> #Run The ROCKET Module
# ---> <a href='vscode-notebook-cell:/Users/mojtabaaskarzadeh/TSC_Repo/CBOSS.ipynb#W2sZmlsZQ%3D%3D?line=36'>37</a> CBOSS_module.CBOSS(results_path, Dataset_name, Dataset, Labels, nb_folds=n_folds, n_parameter_samples= 250,
#      <a href='vscode-notebook-cell:/Users/mojtabaaskarzadeh/TSC_Repo/CBOSS.ipynb#W2sZmlsZQ%3D%3D?line=37'>38</a>                    max_ensemble_size=50, max_win_len_prop = 0.7)
#
# File ~/TSC_Repo/classifiers/CBOSS_module.py:82, in CBOSS(results_path, dataset_name, dataset, labels, nb_folds, n_parameter_samples, max_ensemble_size, max_win_len_prop)
#      78 y_train, y_test = labels[train_idx], labels[test_idx]
#      80 # fit the algorithm on the training data
# ---> 82 classifier.fit(X_train, y_train)
#      83 print("\n The classifier is fitted")
#      85 # make predictions on the testing data
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sktime/classification/base.py:163, in BaseClassifier.fit(self, X, y)
#     160 self._X_metadata = X_metadata
#     162 # Check this classifier can handle characteristics
# --> 163 self._check_capabilities(missing, multivariate, unequal)
#     165 # remember class labels
#     166 self.classes_ = np.unique(y)
#
# File /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/sktime/classification/base.py:647, in BaseClassifier._check_capabilities(self, missing, multivariate, unequal)
#     645     warn(msg)
#     646 else:
# --> 647     raise ValueError(msg)
#
# ValueError: Data seen by ContractableBOSS instance has multivariate series, but this ContractableBOSS instance cannot handle multivariate series. Calls with multivariate series may result in error or unreliable results.
